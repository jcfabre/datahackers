# %% [markdown]
# # pivot_table(),  stack() and unstack() in Pandas

# %% [markdown]
# Inspired from this article: http://pbpython.com/pandas-pivot-table-explained.html

# %% [markdown]
# ### Imports

# %%
% matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
path = "C:\Users\JC\Desktop\datahackers\Tutorials\In progress\Data Sets\\us-500.csv"

df= pd.read_csv(path)
df["sales"] =np.random.randint(30,1500,500)
df["product"] = ["A"]*100 +["B"]*200 +["C"]*200
df.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1        phone2  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email                                  web  sales  \
# 0                jbutt@gmail.com         http://www.bentonjohnbjr.com    478
# 1  josephine_darakjy@darakjy.org     http://www.chanayjeffreyaesq.com   1047
# 2                 art@venere.org       http://www.chemeljameslcpa.com    275
# 3          lpaprocki@hotmail.com  http://www.feltzprintingservice.com   1162
# 4         donette.foller@cox.net    http://www.printingdimensions.com    846
#
#   product
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A

# %% [markdown]
# ### index

# %%
df.pivot_table(index = ["state","county"]).head()
# Out:
#                                   sales           zip
# state county
# AK    Anchorage              982.750000  99504.500000
#       Fairbanks North Star  1131.000000  99710.000000
# AR    Pulaski                995.000000  72202.000000
# AZ    Maricopa               723.555556  85132.000000
# CA    Alameda                704.428571  94586.428571

# %% [markdown]
# The data is automatically __averaged__. Doesn't make sense for zip. We can ask for sales only

# %% [markdown]
# ### values

# %%
df.pivot_table(index = ["state","county"], values = ["sales"]).head()
# Out:
#                                   sales
# state county
# AK    Anchorage              982.750000
#       Fairbanks North Star  1131.000000
# AR    Pulaski                995.000000
# AZ    Maricopa               723.555556
# CA    Alameda                704.428571

# %% [markdown]
# ### aggfunc

# %% [markdown]
# Let's look at the sum, average, min and max of sales thanks to the aggfunc

# %%
df.pivot_table(index = ["state","county"], values = ["sales"], aggfunc = [np.mean, np.sum, np.min, np.max]).head()
# Out:
#                                    mean   sum  amin  amax
#                                   sales sales sales sales
# state county
# AK    Anchorage              982.750000  3931   275  1424
#       Fairbanks North Star  1131.000000  2262   843  1419
# AR    Pulaski                995.000000   995   995   995
# AZ    Maricopa               723.555556  6512    71  1344
# CA    Alameda                704.428571  4931   195  1073

# %% [markdown]
# We can also add a count with len

# %%
df.pivot_table(index = ["state","county"], values = ["sales"], aggfunc = [np.mean, np.sum, np.min, np.max]).head()
# Out:
#                                    mean   sum  amin  amax
#                                   sales sales sales sales
# state county
# AK    Anchorage              982.750000  3931   275  1424
#       Fairbanks North Star  1131.000000  2262   843  1419
# AR    Pulaski                995.000000   995   995   995
# AZ    Maricopa               723.555556  6512    71  1344
# CA    Alameda                704.428571  4931   195  1073

# %% [markdown]
# ### columns

# %% [markdown]
# Let's look at the total sales for each (state, county) tuple split by product

# %%
df.pivot_table(index = ["state","county"], 
               values = ["sales"], 
               columns = ["product"],
               aggfunc = [np.sum,len]).head()
# Out:
#                              sum               len
#                            sales             sales
# product                        A     B     C     A   B   C
# state county
# AK    Anchorage             2861   NaN  1070     3 NaN   1
#       Fairbanks North Star  2262   NaN   NaN     2 NaN NaN
# AR    Pulaski                NaN   995   NaN   NaN   1 NaN
# AZ    Maricopa              1344  1360  3808     1   2   6
# CA    Alameda               1843  2115   973     2   3   2

# %% [markdown]
# ### fill_value

# %% [markdown]
# Now we'd like to replace the NaN by 'No sales'

# %%
df.pivot_table(index = ["state","county"], 
               values = ["sales"], 
               columns = ["product"],
               aggfunc = [np.sum,len],
              fill_value = "No sales").head()
# Out:
#                                  sum                           len            \
#                                sales                         sales
# product                            A         B         C         A         B
# state county
# AK    Anchorage                 2861  No sales      1070         3  No sales
#       Fairbanks North Star      2262  No sales  No sales         2  No sales
# AR    Pulaski               No sales       995  No sales  No sales         1
# AZ    Maricopa                  1344      1360      3808         1         2
# CA    Alameda                   1843      2115       973         2         3
#
#
#
# product                            C
# state county
# AK    Anchorage                    1
#       Fairbanks North Star  No sales
# AR    Pulaski               No sales
# AZ    Maricopa                     6
# CA    Alameda                      2

# %% [markdown]
# Moving product to index for a different visualization

# %%
df.pivot_table(index = ["state","county","product"], 
               values = ["sales"],
               aggfunc = [np.sum,len],
              fill_value = "No sales").head()
# Out:
#                                      sum   len
#                                    sales sales
# state county               product
# AK    Anchorage            A        2861     3
#                            C        1070     1
#       Fairbanks North Star A        2262     2
# AR    Pulaski              B         995     1
# AZ    Maricopa             A        1344     1

# %% [markdown]
# ### Query the table

# %%
table = df.pivot_table(index = ["state","county","product"], 
               values = ["sales"],
               aggfunc = [np.sum,len],
              fill_value = "No sales")
table.head(10)
# Out:
#                                      sum   len
#                                    sales sales
# state county               product
# AK    Anchorage            A        2861     3
#                            C        1070     1
#       Fairbanks North Star A        2262     2
# AR    Pulaski              B         995     1
# AZ    Maricopa             A        1344     1
#                            B        1360     2
#                            C        3808     6
# CA    Alameda              A        1843     2
#                            B        2115     3
#                            C         973     2

# %% [markdown]
# #### with .query method (needs numexpr installed)

# %%
table.query('state == ["CA"]').head()
# Out:
#                              sum   len
#                            sales sales
# state county       product
# CA    Alameda      A        1843     2
#                    B        2115     3
#                    C         973     2
#       Butte        C         973     1
#       Contra Costa A         406     1

# %%
table.query('state == ["CA"] & product == ["A"]').head()
# Out:
#                               sum   len
#                             sales sales
# state county        product
# CA    Alameda       A        1843     2
#       Contra Costa  A         406     1
#       Los Angeles   A        3913     5
#       San Francisco A         674     1
#       San Mateo     A        1904     2

# %% [markdown]
# #### With usual Dataframe methods

# %%
table.loc["NY",(slice(None)),"B"]["sum","sales"]
# Out:
# state  county       product
# NY     Bronx        B          1389
#        Erie         B           292
#        Kings        B           359
#        Nassau       B          1676
#        New York     B          5802
#        Onondaga     B          1320
#        Rensselaer   B          1117
#        Suffolk      B          1485
#        Westchester  B          2497
# Name: (sum, sales), dtype: int32

# %% [markdown]
# (slice(None)) stands for :

# %% [markdown]
# ### unstack()

# %%
table.head()
# Out:
#                                      sum   len
#                                    sales sales
# state county               product
# AK    Anchorage            A        2861     3
#                            C        1070     1
#       Fairbanks North Star A        2262     2
# AR    Pulaski              B         995     1
# AZ    Maricopa             A        1344     1

# %%
table.unstack().head()
# Out:
#                              sum               len
#                            sales             sales
# product                        A     B     C     A   B   C
# state county
# AK    Anchorage             2861   NaN  1070     3 NaN   1
#       Fairbanks North Star  2262   NaN   NaN     2 NaN NaN
# AR    Pulaski                NaN   995   NaN   NaN   1 NaN
# AZ    Maricopa              1344  1360  3808     1   2   6
# CA    Alameda               1843  2115   973     2   3   2

# %% [markdown]
# ### stack()

# %%
df.pivot_table(index=["state"],columns=["product"],values =["sales"]).head()
# Out:
#                sales
# product            A           B            C
# state
# AK       1024.600000         NaN  1070.000000
# AR               NaN  995.000000          NaN
# AZ       1344.000000  680.000000   634.666667
# CA        752.266667  746.774194   738.346154
# CO        224.000000  673.000000   760.250000

# %%
df.pivot_table(index=["state"],columns=["product"],values =["sales"]).stack().head()
# Out:
#                 sales
# state product
# AK    A        1024.6
#       C        1070.0
# AR    B         995.0
# AZ    A        1344.0
#       B         680.0
